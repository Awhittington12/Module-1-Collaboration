# %%
secret = 6
guess = 8
if guess<secret:
    print("Too Low")
elif guess>secret:
    print("Too High")
else:
    print("Just right")
# Out:
# Too High

# %%
Small = True
Green = False
if Small and Green == True:
    print("Pea")
elif Small =
# Out:
# Pea Cherry
# No green items:(
# Pumpkin
